# %%
import sys
sys.path.insert(1, "..")

# %%
from parse_game import ParseGame

# %%
parser = ParseGame()
parser.attach_filepath("../ESP1/738459-Spain-LaLiga-2013-2014-Celta-Vigo-Espanyol.json")

# %%
parser.import_game()

# %%
parser.extract_referee()
parser.referee_data
# Out:
#   MatchId RefereeId                     RefereeName
# 0  738459      1607  José Antonio Teixeira Vitienes

# %%
parser.extract_player_game()
parser.player_game_data
# Out:
#    MatchId PlayerId ShirtNo           PlayerName Position Started  \
# 0   738459    83117      13       Yoel Rodríguez       GK    True
# 0   738459    79929       2           Hugo Mallo       DR    True
# 0   738459    15544      22       Gustavo Cabral       DC    True
# 0   738459    74938       3        Andreu Fontàs       DC    True
# 0   738459   105912      20          Toni Dovale       DL    True
# 0   738459    10623      23  Michael Krohn-Dehli       MC    True
# 0   738459    18219       4         Borja Oubiña       MC    True
# 0   738459    87080       8           Álex López       MC    True
# 0   738459    25956      24    Augusto Fernández      FWR    True
# 0   738459   102157      11              Charles       FW    True
# 0   738459    91267      10               Nolito      FWL    True
# 0   738459   106590      12              Rafinha      Sub   False
# 0   738459   108220      28         Lévy Madinda      Sub   False
# ...

# %%
parser.extract_game()
parser.game_data
# Out:
#   MatchId League     Season VenueName Attendance   StartDate StartTime  \
# 0  738459   ESP1  2013-2014  Balaídos      21672  2013-08-19  21:00:00
#
#   WeatherCode HomeTeamId HomeTeamName  ... AwayTeamId AwayTeamName  \
# 0           5         62   Celta Vigo  ...         70     Espanyol
#
#   AwayTeamManager AwayAvgAge HomeGoals AwayGoals HomeHTGoals AwayHTGoals  \
# 0  Javier Aguirre       32.2         2         2           1           0
#
#   HomeFTGoals AwayFTGoals
# 0           2           2
#
# [1 rows x 22 columns]

# %%
parser.extract_events()
parser.event_data
# Out:
#    MatchId     EventId EventMatchId Minute Second TeamId PlayerId StartX  \
# 0   738459  1956079551            2      0      0     70     None      0
# 0   738459  1972265860            3      0      0     62     None      0
# 0   738459  1217080213            3      0      1     70    81928   50.1
# 0   738459   100258400            4      0      2     70    10060   52.8
# 0   738459  1916349902            5      0      3     70    33495   26.1
# ..     ...         ...          ...    ...    ...    ...      ...    ...
# 0   738459   304820833          856     92     52     62   105912   20.4
# 0   738459  1336410710          741     93      3     70     None      0
# 0   738459  2022470689          858     93      3     62     None      0
# 0   738459  1378734642            1      0      0     70     None      0
# 0   738459   589537459            1      0      0     62     None      0
#
#    StartY        Half          Type       Outcome  EndX  EndY
# ...
